# %% [markdown]
# # V_Liachenko_capstone_task3_a_scrapping&preprocessing_wikipedia_10marks

# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests
import numpy as np
from geopy.geocoders import Nominatim
from pandas.io.json import json_normalize
from sklearn.cluster import KMeans
import matplotlib.cm as cm
import matplotlib.colors as colors
print ("Libraries imported")
# Out:
# Libraries imported

# %%
source = requests.get("https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M").text
soup = BeautifulSoup(source, 'lxml')

table = soup.find("table")
table_rows = table.tbody.find_all("tr")

res = []
for tr in table_rows:
    td = tr.find_all("td")
    row = [tr.text for tr in td]
    
    # Processing the cells that have an assigned borough only.
    if row != [] and row[1] != "Not assigned":
        # If a cell has a borough but a "Not assigned" neighborhood, then the neighborhood will be the same as the borough.
        if "Not assigned" in row[2]: 
            row[2] = row[1]
        res.append(row)

df = pd.DataFrame(res, columns = ["PostalCode", "Borough", "Neighborhood"])
df.head()
# Out:
#   PostalCode             Borough                 Neighborhood
# 0      M1A\n      Not assigned\n               Not assigned\n
# 1      M2A\n      Not assigned\n               Not assigned\n
# 2      M3A\n        North York\n                  Parkwoods\n
# 3      M4A\n        North York\n           Victoria Village\n
# 4      M5A\n  Downtown Toronto\n  Regent Park, Harbourfront\n

# %%
# Preprocessing: Remove "\n" at the end of each string in the Neighborhood, Borough and PostalCode columns and group all neighborhoods with the same postal code
df["Neighborhood"] = df["Neighborhood"].str.replace("\n","")
df["PostalCode"] = df["PostalCode"].str.replace("\n","")
df["Borough"] = df["Borough"].str.replace("\n","")
df = df.groupby(["PostalCode", "Borough"])["Neighborhood"].apply(", ".join).reset_index()
df.head()
# Out:
#   PostalCode       Borough                            Neighborhood
# 0        M1A  Not assigned                            Not assigned
# 1        M1B   Scarborough                          Malvern, Rouge
# 2        M1C   Scarborough  Rouge Hill, Port Union, Highland Creek
# 3        M1E   Scarborough       Guildwood, Morningside, West Hill
# 4        M1G   Scarborough                                  Woburn

# %%
print("Shape: ", df.shape)
# Out:
# Shape:  (180, 3)

# %% [markdown]
# # V_Liachenko_capstone_task3_b_getting_longitude&latitude_2marks

# %%
df_coordinates = pd.read_csv("https://cocl.us/Geospatial_data")
df_coordinates.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
# Merging two dataframes: df and df_coordinates together
df_toronto = pd.merge(df, df_coordinates, how='left', left_on = 'PostalCode', right_on = 'Postal Code')
df_toronto.drop("Postal Code", axis=1, inplace=True)
df_toronto.head()
# Out:
#   PostalCode       Borough                            Neighborhood   Latitude  \
# 0        M1A  Not assigned                            Not assigned        NaN
# 1        M1B   Scarborough                          Malvern, Rouge  43.806686
# 2        M1C   Scarborough  Rouge Hill, Port Union, Highland Creek  43.784535
# 3        M1E   Scarborough       Guildwood, Morningside, West Hill  43.763573
# 4        M1G   Scarborough                                  Woburn  43.770992
#
#    Longitude
# 0        NaN
# 1 -79.194353
# 2 -79.160497
# 3 -79.188711
# 4 -79.216917

# %%
df_toronto
# Out:
#     PostalCode       Borough  \
# 0          M1A  Not assigned
# 1          M1B   Scarborough
# 2          M1C   Scarborough
# 3          M1E   Scarborough
# 4          M1G   Scarborough
# ..         ...           ...
# 175        M9V     Etobicoke
# 176        M9W     Etobicoke
# 177        M9X  Not assigned
# 178        M9Y  Not assigned
# 179        M9Z  Not assigned
#
#                                           Neighborhood   Latitude  Longitude
# 0                                         Not assigned        NaN        NaN
# 1                                       Malvern, Rouge  43.806686 -79.194353
# 2               Rouge Hill, Port Union, Highland Creek  43.784535 -79.160497
# 3                    Guildwood, Morningside, West Hill  43.763573 -79.188711
# 4                                               Woburn  43.770992 -79.216917
# ..                                                 ...        ...        ...
# ...

# %%
print("Shape: ", df_toronto.shape)
# Out:
# Shape:  (180, 5)

# %%
df_toronto.dropna(subset = ["Latitude"], inplace=True)
df_toronto.dropna(subset = ["Longitude"], inplace=True)
df_toronto
# Out:
#     PostalCode      Borough  \
# 1          M1B  Scarborough
# 2          M1C  Scarborough
# 3          M1E  Scarborough
# 4          M1G  Scarborough
# 5          M1H  Scarborough
# ..         ...          ...
# 170        M9N         York
# 171        M9P    Etobicoke
# 172        M9R    Etobicoke
# 175        M9V    Etobicoke
# 176        M9W    Etobicoke
#
#                                           Neighborhood   Latitude  Longitude
# 1                                       Malvern, Rouge  43.806686 -79.194353
# 2               Rouge Hill, Port Union, Highland Creek  43.784535 -79.160497
# 3                    Guildwood, Morningside, West Hill  43.763573 -79.188711
# 4                                               Woburn  43.770992 -79.216917
# 5                                            Cedarbrae  43.773136 -79.239476
# ..                                                 ...        ...        ...
# 170                                             Weston  43.706876 -79.518188
# ...

# %%
print("Shape: ", df_toronto.shape)
# Out:
# Shape:  (103, 5)

# %% [markdown]
# # V_Liachenko_capstone_task3_c_clustering_neighbourhoods_Toronto_3marks

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation


# !pip install geopy
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# Tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize


! pip install folium==0.5.0
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# ...
#      |████████████████████████████████| 79 kB 11.1 MB/s eta 0:00:01
# ...
#   Created wheel for folium: filename=folium-0.5.0-py3-none-any.whl size=76240 sha256=45ce009b08da59b123fdf3c62ef394218797d0085320885c6e49dc495663bb81
#   Stored in directory: /tmp/wsuser/.cache/pip/wheels/b2/2f/2c/109e446b990d663ea5ce9b078b5e7c1a9c45cca91f377080f8
# Successfully built folium
# ...
# Folium installed
# Libraries imported.

# %%
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values
from pandas.io.json import json_normalize  # tranform JSON file into a pandas dataframe

# import k-means from clustering stage
from sklearn.cluster import KMeans

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors
print('Libraries imported.')
# Out:
# Libraries imported.

# %%
Toronto = "Toronto, ON"

geolocator = Nominatim(user_agent="toronto_explorer")
location = geolocator.geocode(Toronto)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronto city are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Toronto city are 43.6534817, -79.3839347.

# %%
# Creating map of Toronto using latitude and longitude values
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=10)
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Adding markers to Toronto
for lat, lng, borough, neighborhood in zip(
        df_toronto['Latitude'], 
        df_toronto['Longitude'], 
        df_toronto['Borough'], 
        df_toronto['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='green',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  

map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Leaving boroughs with the word "Toronto" only
df_toronto_only = df_toronto[df_toronto['Borough'].str.contains("Toronto")].reset_index(drop=True)
df_toronto_only.head()
# Out:
#   PostalCode          Borough                    Neighborhood   Latitude  \
# 0        M4E     East Toronto                     The Beaches  43.676357
# 1        M4K     East Toronto    The Danforth West, Riverdale  43.679557
# 2        M4L     East Toronto  India Bazaar, The Beaches West  43.668999
# 3        M4M     East Toronto                 Studio District  43.659526
# 4        M4N  Central Toronto                   Lawrence Park  43.728020
#
#    Longitude
# 0 -79.293031
# 1 -79.352188
# 2 -79.315572
# 3 -79.340923
# 4 -79.388790

# %%
map_toronto_only = folium.Map(location=[latitude, longitude], zoom_start=12)
for lat, lng, borough, neighborhood in zip(
        df_toronto_only['Latitude'], 
        df_toronto_only['Longitude'], 
        df_toronto_only['Borough'], 
        df_toronto_only['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='green',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto_only)  

map_toronto_only
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Applying Kmeans
k=5
toronto_clustering = df_toronto_only.drop(['PostalCode','Borough','Neighborhood'],1)
kmeans = KMeans(n_clusters = k,random_state=0).fit(toronto_clustering)
kmeans.labels_
df_toronto_only.insert(0, 'Cluster Labels', kmeans.labels_)

# %%
df_toronto_only
# Out:
#     Cluster Labels PostalCode           Borough  \
# 0                4        M4E      East Toronto
# 1                4        M4K      East Toronto
# 2                4        M4L      East Toronto
# 3                4        M4M      East Toronto
# 4                2        M4N   Central Toronto
# 5                2        M4P   Central Toronto
# 6                2        M4R   Central Toronto
# 7                2        M4S   Central Toronto
# 8                2        M4T   Central Toronto
# 9                2        M4V   Central Toronto
# 10               1        M4W  Downtown Toronto
# 11               1        M4X  Downtown Toronto
# 12               1        M4Y  Downtown Toronto
# 13               1        M5A  Downtown Toronto
# 14               1        M5B  Downtown Toronto
# 15               1        M5C  Downtown Toronto
# 16               1        M5E  Downtown Toronto
# 17               1        M5G  Downtown Toronto
# ...

# %%
# Creating cluster map of Toronto
toronto_map_clusters = folium.Map(location=[43.651070,-79.347015],zoom_start=12)

# Setting color scheme for the clusters
x = np.arange(k)
ys = [i + x + (i*x)**2 for i in range(k)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# Adding markers to the map
markers_colors = []
for lat, lon, neighborhood, cluster in zip(df_toronto_only['Latitude'], df_toronto_only['Longitude'], df_toronto_only['Neighborhood'], df_toronto_only['Cluster Labels']):
    label = folium.Popup(' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(toronto_map_clusters)
       
toronto_map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
